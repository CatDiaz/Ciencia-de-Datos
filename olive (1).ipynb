# %%
import pandas as pd

# %%
olive=pd.read_csv('/Users/RomanCastillo/Desktop/olive.csv')

# %%
# muestra los primeros registros
olive.head()
# Out:
#    Unnamed: 0  Region          Area  palmitic  palmitoleic  stearic  oleic  \
# 0           1       1  North-Apulia      1075           75      226   7823
# 1           2       1  North-Apulia      1088           73      224   7709
# 2           3       1  North-Apulia       911           54      246   8113
# 3           4       1  North-Apulia       966           57      240   7952
# 4           5       1  North-Apulia      1051           67      259   7771
#
#    linoleic  linolenic  arachidic  eicosenoic
# 0       672         36         60          29
# 1       781         31         61          29
# 2       549         31         63          29
# 3       619         50         78          35
# 4       672         50         80          46

# %%
# Cantidad de registros

print(olive.shape)

# Nombre de columnas 
print(olive.columns)
# Out:
# (572, 11)
# Index(['Unnamed: 0', 'Region', 'Area', 'palmitic', 'palmitoleic', 'stearic',
#        'oleic', 'linoleic', 'linolenic', 'arachidic', 'eicosenoic'],
#       dtype='object')

# %%
# Resumen de variables numericas
olive.describe()
# Out:
#        Unnamed: 0      Region     palmitic  palmitoleic     stearic  \
# count  572.000000  572.000000   572.000000   572.000000  572.000000
# mean   286.500000    1.699301  1231.741259   126.094406  228.865385
# std    165.266452    0.859968   168.592264    52.494365   36.744935
# min      1.000000    1.000000   610.000000    15.000000  152.000000
# 25%    143.750000    1.000000  1095.000000    87.750000  205.000000
# 50%    286.500000    1.000000  1201.000000   110.000000  223.000000
# 75%    429.250000    3.000000  1360.000000   169.250000  249.000000
# max    572.000000    3.000000  1753.000000   280.000000  375.000000
#
#              oleic     linoleic   linolenic   arachidic  eicosenoic
# count   572.000000   572.000000  572.000000  572.000000  572.000000
# mean   7311.748252   980.527972   31.888112   58.097902   16.281469
# std     405.810222   242.799221   12.968697   22.030250   14.083295
# min    6300.000000   448.000000    0.000000    0.000000    1.000000
# ...

# %%
olive\
    .drop(columns=['Unnamed: 0'])\
    .groupby('Region')\
    .agg('mean')
# Out:
#            palmitic  palmitoleic     stearic        oleic     linoleic  \
# Region
# 1       1332.287926   154.801858  228.773994  7100.009288  1033.498452
# 2       1111.346939    96.744898  226.183673  7268.020408  1196.530612
# 3       1094.801325    83.735099  230.801325  7793.052980   727.033113
#
#         linolenic  arachidic  eicosenoic
# Region
# 1       38.065015  63.117647   27.321981
# 2       27.091837  73.173469    1.938776
# 3       21.788079  37.576159    1.973510

# %%
olive\
    .drop(columns=['Unnamed: 0','Region'])\
    .groupby('Area')\
    .agg('mean')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\100019~1\AppData\Local\Temp/ipykernel_4512/3758331757.py in <module>
# ----> 1 olive\
#       2     .drop(columns=['Unnamed: 0','Region'])\
#       3     .groupby('Area')\
#       4     .agg('mean')
#
# NameError: name 'olive' is not defined

# %%
import matplotlib

print(matplotlib.__version__)
# Out:
# 3.4.3

# %%
import matplotlib.pyplot as plot
import pandas as pd
